# %%
import pandas as pd 

data= pd.read_csv('wifi_signal.csv')

df= pd.DataFrame(data)

df.head(10)
# Out:
#     timestamp  rssi      label
# 0  1755520197   -44  no_motion
# 1  1755520198   -45  no_motion
# 2  1755520204   -58  no_motion
# 3  1755520205   -48  no_motion
# 4  1755520206   -45  no_motion
# 5  1755520207   -51  no_motion
# 6  1755520208   -46  no_motion
# 7  1755520214   -42  no_motion
# 8  1755520215   -48  no_motion
# 9  1755520216   -54  no_motion

# %%
import matplotlib.pyplot as pl

pl.plot(df['timestamp'],df['rssi'])
